# %% [markdown]
# <a href="https://colab.research.google.com/github/harabou/NCD_biostat/blob/main/%2303_General_linear_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #03 General linear model(1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Data set

fpath = 'https://raw.githubusercontent.com/harabou/DS-AI_course/refs/heads/main/%2303/Ans1.csv'

Ans1 = pd.read_csv(fpath,header=0, encoding='shift-jis')

# %% [markdown]
# 変数取り出しで作成パターン

# %%
# Objective variables are taken from the data frame and converted to a numpy array
y = Ans1["y"].to_numpy()

# Objective variables are taken from the data frame and converted to a numpy array
# (Note that the parentheses are doubled to make it a two-dimensional array)
X = Ans1[["x"]].to_numpy()

# %%
#回帰
model = LinearRegression()
model.fit(Ans1[['x']], Ans1['y']) # Changed Ans1.x to Ans1[['x']] to make it a DataFrame
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split


# Split data into training and validation data
# Use 70% of data for training and 30% for validation
X_train, X_test, y_train, y_test = train_test_split(X, y, \
                                  test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# Generate regression analysis model
model = LinearRegression()

# Fitting with training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 1.3877275 ,  3.47859738,  0.83429753, -0.32870416, -2.49885845,
#         0.03452377,  0.09743634, -0.16074142, -0.01526365,  0.06636343,
#         0.01156962,  0.00909425, -0.02796359,  0.05811773,  0.103679  ])

# %%
# regression coefficient
a = model.coef_[0]

# Intercept
b = model.intercept_

print("回帰係数    ", a)
print("切片        ", b)
# Out:
# 回帰係数     0.5000909090909093
# 切片         3.0000909090909094

# %%
# Accuracy of Prediction
print("R2 value for training data")
print(model.score(X_train,y_train))

print()

print("R2 value for test data")
print(model.score(X_test,y_test))
# Out:
# 訓練データに対する精度(R2値)
# 0.8260970641499348
#
# テストデータに対する精度(R2値)
# 0.13434537986046768
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Patterns created with Statsmodel

# %%
import statsmodels.api as sm
fpath = 'https://raw.githubusercontent.com/harabou/DS-AI_course/refs/heads/main/%2303/Ans1.csv'

Ans1 = pd.read_csv(fpath,header=0, encoding='shift-jis')

# %%
X= Ans1.x
Y= Ans1.y

model = sm.OLS(X, Y)
result = model.fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared (uncentered):                   0.963
# Model:                            OLS   Adj. R-squared (uncentered):              0.959
# Method:                 Least Squares   F-statistic:                              257.9
# Date:                Wed, 26 Feb 2025   Prob (F-statistic):                    1.81e-08
# Time:                        08:58:08   Log-Likelihood:                         -22.334
# No. Observations:                  11   AIC:                                      46.67
# Df Residuals:                      10   BIC:                                      47.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#
x = Ans1[[x1, x2]]
y = Ans1.y
model=sm.0LS(Y,X)
result = model.fit()
result.summary()

# %%
plt.scatter(x=X,y=Y) and plt.plot(X,
model.fit ().predict( X), c="red")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
import numpy as np

# Dataset

fpath = 'https://raw.githubusercontent.com/harabou/DS-AI_course/refs/heads/main/%2303/select.csv'

select = pd.read_csv(fpath,header=0, encoding='shift-jis')

# %%
# x,y分割するとき、ｘはｙだけ落としたものにする
df_x = select.drop('y', axis=1)
df_y = select['y']

# %%
from sklearn.linear_model import LinearRegression

# Generate regression analysis model
model = LinearRegression()

# Fitting with training data
model.fit(df_x, df_y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 1.3877275 ,  3.47859738,  0.83429753, -0.32870416, -2.49885845,
#         0.03452377,  0.09743634, -0.16074142, -0.01526365,  0.06636343,
#         0.01156962,  0.00909425, -0.02796359,  0.05811773,  0.103679  ])

# %%
pred_y = model.predict(df_x)

print('決定係数（r2）:{}'.format(round(r2_score(df_y, pred_y),3)))
print('平均誤差（MAE）:{}'.format(round(mean_absolute_error(df_y, pred_y),3)))
print('RMSE:{}'.format(round(np.sqrt(mean_squared_error(df_y, pred_y)),3)))
# Out:
# 決定係数（r2）:0.736
# 平均誤差（MAE）:0.796
# RMSE:0.997

# %%
# Prediction-Measurement Plot
plt.figure(figsize=(6,6))
plt.scatter(df_y, pred_y,color='blue',alpha=0.3)
y_max_ = max(df_y.max(), pred_y.max())
y_min_ = min(df_y.min(), pred_y.min())
y_max = y_max_ + (y_max_ - y_min_) * 0.1
y_min = y_min_ - (y_max_ - y_min_) * 0.1

plt.plot([y_min , y_max],[y_min, y_max], 'k-')

plt.ylim(y_min, y_max)
plt.xlim(y_min, y_max)
plt.xlabel('alcohol(observed)',fontsize=20)
plt.ylabel('alcohol(predicted)',fontsize=20)
plt.legend(loc='best',fontsize=15)
plt.title('yyplot(alcohol)',fontsize=20)
plt.savefig('yyplot.png')
plt.show()

print('回帰係数：',round(model.intercept_,3))
# Out:
# <ipython-input-47-9d442ff39627>:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best',fontsize=15)
# 回帰係数： 0.024

# %%
#Display of a pandasDataFrame containing regression coefficients
df_coef =  pd.DataFrame({'coefficient':model.coef_.flatten()}, index=df_x.columns)

# %%
x_pos = np.arange(len(df_coef))

fig = plt.figure(figsize=(6,6))
ax1 = fig.add_subplot(1, 1, 1)
ax1.barh(x_pos, df_coef['coefficient'], color='b')
ax1.set_title('coefficient of variables',fontsize=18)
ax1.set_yticks(x_pos)
ax1.set_yticks(np.arange(-1,len(df_coef.index))+0.5, minor=True)
ax1.set_yticklabels(df_coef.index, fontsize=14)
ax1.set_xticks(np.arange(-3,4,2)/10)
ax1.set_xticklabels(np.arange(-3,4,2)/10,fontsize=12)
ax1.grid(which='minor',axis='y',color='black',linestyle='-', linewidth=1)
ax1.grid(which='major',axis='x',linestyle='--', linewidth=1)
plt.savefig('coef_sklearn.png',bbox_inches='tight')
plt.show()

# %%
# データフレームから目的変数を取り出し、numpyの配列に変換
y = Ans1["y"].to_numpy()

# データフレームから説明変数を取り出し、numpyの配列に変換
# （二次元配列にするために括弧が二重になるので注意）
X = Ans1[["x"]].to_numpy()
