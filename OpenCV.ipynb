# %% [markdown]
# # OpenCVによる画像処理

# %% [markdown]
# Googleドライブをマウントする

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 画像の読み込み
# ## Loading Images

# %% [markdown]
# 画像ファイルを読み込む

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 画像ファイルを保存したgoogleドライブのフォルダの指定
# 自分の環境に合わせて書き換えること
# Specify google drive folder where image files are stored
# To be rewritten to suit your environment.

dir_path = '/content/drive/MyDrive/AI/'

# 画像ファイルの読み込み
# Load image files
img = cv2.imread(dir_path + "Pepper.jpg")

# 配列のサイズを画面に表示
print(img.shape)
# Out:
# (150, 150, 3)

# %% [markdown]
# 読み込んだ画像を画面に表示する

# %%
plt.imshow(img)

# %% [markdown]
# 色情報の保存の仕方をBGRからRGBに変更する

# %%
# BGRからRGBに変換
# Change the way color information is stored from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %% [markdown]
# # 画像の回転
# # Image Rotation

# %% [markdown]
# 時計回りに90度回転させる

# %%
img_rotate1 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

plt.imshow(img_rotate1)

# %% [markdown]
# 反時計回りに90度回転させる

# %%
img_rotate2 = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

plt.imshow(img_rotate2)

# %% [markdown]
# 180度回転させる

# %%
img_rotate3 = cv2.rotate(img, cv2.ROTATE_180)

plt.imshow(img_rotate3)

# %% [markdown]
# ## 画像の反転

# %% [markdown]
# 上下に反転させる

# %%
img_flip1 = cv2.flip(img, 0)

plt.imshow(img_flip1)

# %% [markdown]
# 左右に反転させる

# %%
img_flip2 = cv2.flip(img, 1)

plt.imshow(img_flip2)

# %% [markdown]
# 上下にも左右にも反転させる

# %%
img_flip3 = cv2.flip(img, -1)

plt.imshow(img_flip3)

# %% [markdown]
# ## 画像のトリミング

# %% [markdown]
# 配列の範囲を指定して画像の一部分をトリミングする

# %%
img_trim = img[50:150, 50:130]

plt.imshow(img_trim)

# %% [markdown]
# ## 画像の拡大、縮小

# %% [markdown]
# 画素数300 x 300に拡大する

# %%
img_large = cv2.resize(img, (300, 300))

plt.imshow(img_large)

# %% [markdown]
# 画素数70 x 70に縮小する

# %%
img_small = cv2.resize(img, (70, 70))

plt.imshow(img_small)
